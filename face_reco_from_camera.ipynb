# %%
# 攝像頭即時人臉識別
# Real-time face recognition

# Author:   coneypo
# Blog:     http://www.cnblogs.com/AdaminXie
# GitHub:   https://github.com/coneypo/Dlib_face_recognition_from_camera

# Created at 2018-05-11
# Updated at 2020-05-29

import dlib         # 人臉處理的庫 Dlib
import numpy as np  # 資料處理的庫 Numpy
import cv2          # 影像處理的庫 OpenCV
import pandas as pd # 資料處理的庫 Pandas
import os
import time
from PIL import Image, ImageDraw, ImageFont
import freetype

# 1. Dlib 正向人臉檢測器
detector = dlib.get_frontal_face_detector()

# 2. Dlib 人臉 landmark 特徵點檢測器
predictor = dlib.shape_predictor('data/data_dlib/shape_predictor_68_face_landmarks.dat')

# 3. Dlib Resnet 人臉識別模型，提取 128D 的特徵向量
face_reco_model = dlib.face_recognition_model_v1("data/data_dlib/dlib_face_recognition_resnet_model_v1.dat")


class Face_Recognizer:
    def __init__(self):
        # 用來存放所有錄入人臉特徵的陣列 / Save the features of faces in the database
        self.features_known_list = []

        # 存儲錄入人臉名字 / Save the name of faces known
        self.name_known_cnt = 0
        self.name_known_list = []

        # 存儲當前攝像頭中捕獲到的所有人臉的座標名字 / Save the positions and names of current faces captured
        self.pos_camera_list = []
        self.name_camera_list = []
        # 存儲當前攝像頭中捕獲到的人臉數
        self.faces_cnt = 0
        # 存儲當前攝像頭中捕獲到的人臉特徵
        self.features_camera_list = []

        # Update FPS
        self.fps = 0
        self.frame_start_time = 0

    # 從 "features_all.csv" 讀取錄入人臉特徵
    def get_face_database(self):
        if os.path.exists("data/features_all.csv"):
            path_features_known_csv = "data/features_all.csv"
            csv_rd = pd.read_csv(path_features_known_csv, header=None)
            # 2. 讀取已知人臉資料 / Print known faces
            for i in range(csv_rd.shape[0]):
                features_someone_arr = []
                for j in range(0, 128):
                    if csv_rd.iloc[i][j] == '':
                        features_someone_arr.append('0')
                    else:
                        features_someone_arr.append(csv_rd.iloc[i][j])
                self.features_known_list.append(features_someone_arr)
                self.name_known_list.append("Person_"+str(i+1))
            self.name_known_cnt = len(self.name_known_list)
            print("Faces in Database：", len(self.features_known_list))
            return 1
        else:
            print('##### Warning #####', '\n')
            print("'features_all.csv' not found!")
            print(
                "Please run 'get_faces_from_camera.py' and 'features_extraction_to_csv.py' before 'face_reco_from_camera.py'",
                '\n')
            print('##### End Warning #####')
            return 0

    # 計算兩個128D向量間的歐式距離 / Compute the e-distance between two 128D features
    @staticmethod
    def return_euclidean_distance(feature_1, feature_2):
        feature_1 = np.array(feature_1)
        feature_2 = np.array(feature_2)
        dist = np.sqrt(np.sum(np.square(feature_1 - feature_2)))
        return dist

    # 更新 FPS / Update FPS of Video stream
    def update_fps(self):
        now = time.time()
        self.frame_time = now - self.frame_start_time
        self.fps = 1.0 / self.frame_time
        self.frame_start_time = now

    def draw_note(self, img_rd):
        font = cv2.FONT_ITALIC

        cv2.putText(img_rd, "Face Recognizer", (20, 40), font, 1, (255, 255, 255), 1, cv2.LINE_AA)
        cv2.putText(img_rd, "FPS:   " + str(self.fps.__round__(2)), (20, 100), font, 0.8, (0, 255, 0), 1, cv2.LINE_AA)
        cv2.putText(img_rd, "Faces: " + str(self.faces_cnt), (20, 140), font, 0.8, (0, 255, 0), 1, cv2.LINE_AA)
        cv2.putText(img_rd, "Q: Quit", (20, 450), font, 0.8, (255, 255, 255), 1, cv2.LINE_AA)

    def draw_name(self, img_rd):
        # 在人臉框下面寫人臉名字 / Write names under rectangle
        #寫入中文 無法使用cv2.putText 使用draw _需解決 _imaging C module error in python PIL
        #font = ImageFont.truetype(face, 30)
        #img = Image.fromarray(cv2.cvtColor(img_rd, cv2.COLOR_BGR2RGB))
        #draw = ImageDraw.Draw(img)
        
        font = cv2.FONT_ITALIC
        img=cv2.cvtColor(img_rd, cv2.COLOR_BGR2RGB)
        for i in range(self.faces_cnt):
            cv2.putText(img, self.name_camera_list[i], self.pos_camera_list[i], font, 0.8, (0, 255, 255), 1, cv2.LINE_AA)
            #draw.text(xy=self.pos_camera_list[i], text=self.name_camera_list[i],font=font)
            img_with_name = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
        return img_with_name

    # 修改顯示人名
    def modify_name_camera_list(self):
        # Default known name: person_1, person_2, person_3
        self.name_known_list[0] ='Roger'.encode('utf-8').decode()
        self.name_known_list[1] ='Jinwei'.encode('utf-8').decode()
        self.name_known_list[2] ='Liz'.encode('utf-8').decode()
        # self.name_known_list[3] ='xx'.encode('utf-8').decode()
        # self.name_known_list[4] ='xx'.encode('utf-8').decode()

    # 處理獲取的視頻流，進行人臉識別 / Input video stream and face reco process
    def process(self, stream):
        # 1. 讀取存放所有人臉特徵的 csv
        if self.get_face_database():
            while stream.isOpened():
                flag, img_rd = stream.read()
                faces = detector(img_rd, 0)
                kk = cv2.waitKey(1)
                # 按下 q 鍵退出 / Press 'q' to quit
                if kk == ord('q'):
                    break
                else:
                    self.draw_note(img_rd)
                    self.features_camera_list = []
                    self.faces_cnt = 0
                    self.pos_camera_list = []
                    self.name_camera_list = []

                    # 2. 檢測到人臉 / when face detected
                    if len(faces) != 0:
                        # 3. 獲取當前捕獲到的圖像的所有人臉的特徵，存儲到 self.features_camera_list
                        # 3. Get the features captured and save into self.features_camera_list
                        for i in range(len(faces)):
                            shape = predictor(img_rd, faces[i])
                            self.features_camera_list.append(face_reco_model.compute_face_descriptor(img_rd, shape))

                        # 4. 遍歷捕獲到的圖像中所有的人臉 / Traversal all the faces in the database
                        for k in range(len(faces)):
                            print("##### camera person", k + 1, "#####")
                            # 讓人名跟隨在矩形框的下方
                            # 確定人名的位置座標
                            # 先預設所有人不認識，是 unknown
                            # Set the default names of faces with "unknown"
                            self.name_camera_list.append("unknown")

                            # 每個捕獲人臉的名字座標 / Positions of faces captured
                            self.pos_camera_list.append(tuple(
                                [faces[k].left(), int(faces[k].bottom() + (faces[k].bottom() - faces[k].top()) / 4)]))

                            # 5. 對於某張人臉，遍歷所有存儲的人臉特徵
                            # For every faces detected, compare the faces in the database
                            e_distance_list = []
                            for i in range(len(self.features_known_list)):
                                # 如果 person_X 資料不為空
                                if str(self.features_known_list[i][0]) != '0.0':
                                    print("with person", str(i + 1), "the e distance: ", end='')
                                    e_distance_tmp = self.return_euclidean_distance(self.features_camera_list[k],
                                                                                    self.features_known_list[i])
                                    print(e_distance_tmp)
                                    e_distance_list.append(e_distance_tmp)
                                else:
                                    # 空數據 person_X
                                    e_distance_list.append(999999999)
                            # 6. 尋找出最小的歐式距離匹配 / Find the one with minimum e distance
                            similar_person_num = e_distance_list.index(min(e_distance_list))
                            print("Minimum e distance with person", self.name_known_list[similar_person_num])

                            if min(e_distance_list) < 0.4:
                                self.name_camera_list[k] = self.name_known_list[similar_person_num]
                                print("May be person " + str(self.name_known_list[similar_person_num]))
                            else:
                                print("Unknown person")

                            # 矩形框 / Draw rectangle
                            for kk, d in enumerate(faces):
                                # 繪製矩形框
                                cv2.rectangle(img_rd, tuple([d.left(), d.top()]), tuple([d.right(), d.bottom()]),
                                              (0, 255, 255), 2)
                            print('\n')

                        self.faces_cnt = len(faces)
                        # 7. 在這裡更改顯示的人名 / Modify name if needed
                        self.modify_name_camera_list()
                        # 8. 寫名字 / Draw name
                        # self.draw_name(img_rd)
                        img_with_name = self.draw_name(img_rd)
                    else:
                        img_with_name = img_rd

                print("Faces in camera now:", self.name_camera_list, "\n")

                cv2.imshow("camera", img_with_name)

                # 9. 更新 FPS / Update stream FPS
                self.update_fps()

    # OpenCV 調用攝像頭並進行 process
    def run(self):
        cap = cv2.VideoCapture(0)
        cap.set(3, 480)
        self.process(cap)

        cap.release()
        cv2.destroyAllWindows()


def main():
    Face_Recognizer_con = Face_Recognizer()
    Face_Recognizer_con.run()


if __name__ == '__main__':
    main()
# Out:
# Faces in Database： 3
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25898752119882057
# with person 2 the e distance: 0.4112400321415503
# with person 3 the e distance: 0.45969000587504727
# Minimum e distance with person Person_1
# May be person Person_1
#
#
# Faces in camera now: ['Person_1']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2218227696751334
# with person 2 the e distance: 0.42038175654894233
# with person 3 the e distance: 0.4399015396830714
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23697681497117407
# with person 2 the e distance: 0.41232442204857983
# with person 3 the e distance: 0.43404342365977683
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2499137916239557
# with person 2 the e distance: 0.42507528323939553
# with person 3 the e distance: 0.4217969519555084
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2126643646742553
# with person 2 the e distance: 0.38346524129527065
# with person 3 the e distance: 0.386491481060214
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22855940687590143
# with person 2 the e distance: 0.3807901205878033
# with person 3 the e distance: 0.3995668854707657
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22753805334030106
# with person 2 the e distance: 0.40188905900601996
# with person 3 the e distance: 0.42850789000973133
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22105612649294
# with person 2 the e distance: 0.4065323945997683
# with person 3 the e distance: 0.4248671016306703
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24529045745982406
# with person 2 the e distance: 0.41233725776121133
# with person 3 the e distance: 0.442753366732379
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23300047437977198
# with person 2 the e distance: 0.4227509979716535
# with person 3 the e distance: 0.4571724480108021
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24319078679856257
# with person 2 the e distance: 0.4112954631661526
# with person 3 the e distance: 0.4151189271079193
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24064364612530156
# with person 2 the e distance: 0.3954579449116703
# with person 3 the e distance: 0.41302892536018343
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2419430996554932
# with person 2 the e distance: 0.40942364965426453
# with person 3 the e distance: 0.4271714578728085
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2360115782184965
# with person 2 the e distance: 0.3887267960113581
# with person 3 the e distance: 0.42714652586539675
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2559931118736376
# with person 2 the e distance: 0.3711143408828757
# with person 3 the e distance: 0.4193949160520444
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24020449200008043
# with person 2 the e distance: 0.4030003258143306
# with person 3 the e distance: 0.4295948862000381
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24096717977755122
# with person 2 the e distance: 0.40904462325186414
# with person 3 the e distance: 0.4138513215435986
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24592629169357078
# with person 2 the e distance: 0.415699961377464
# with person 3 the e distance: 0.4295402899017581
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23833758223505186
# with person 2 the e distance: 0.40042604720372704
# with person 3 the e distance: 0.4172448612512142
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2445273476256793
# with person 2 the e distance: 0.40375343361996313
# with person 3 the e distance: 0.41973466705958506
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2396192458531638
# with person 2 the e distance: 0.3943841254955356
# with person 3 the e distance: 0.4024160335756011
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25745636151239076
# with person 2 the e distance: 0.40762669507380433
# with person 3 the e distance: 0.4510022137601627
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2232434184708484
# with person 2 the e distance: 0.39495714934166615
# with person 3 the e distance: 0.4094115356656062
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23218423435201832
# with person 2 the e distance: 0.37693629623882524
# with person 3 the e distance: 0.3863860919937643
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2322671861306045
# with person 2 the e distance: 0.40219601066380317
# with person 3 the e distance: 0.38583513158099714
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22003928734636538
# with person 2 the e distance: 0.3851015757413282
# with person 3 the e distance: 0.3947463027349183
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24811542123891017
# with person 2 the e distance: 0.39753300580701345
# with person 3 the e distance: 0.4357573906307778
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
# ##### camera person 1 #####
# with person 1 the e distance: 0.24418018138224457
# with person 2 the e distance: 0.3970685490195122
# with person 3 the e distance: 0.41049542582740634
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22628361820482534
# with person 2 the e distance: 0.40489963933701106
# with person 3 the e distance: 0.4098404301041329
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22717820855787973
# with person 2 the e distance: 0.379749503727961
# with person 3 the e distance: 0.4046092148232037
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22837826312891193
# with person 2 the e distance: 0.3896897812263197
# with person 3 the e distance: 0.4155343692638521
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24030704070058573
# with person 2 the e distance: 0.4011140708238967
# with person 3 the e distance: 0.42237158900843613
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24125264531544388
# with person 2 the e distance: 0.39412383982870924
# with person 3 the e distance: 0.45368263800305747
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23632133305121603
# with person 2 the e distance: 0.3896970337603186
# with person 3 the e distance: 0.42167895942636663
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2500173326521383
# with person 2 the e distance: 0.37079757991931256
# with person 3 the e distance: 0.4058000904791743
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22141641168561207
# with person 2 the e distance: 0.38944226902258616
# with person 3 the e distance: 0.4134787223542321
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2161290652893508
# with person 2 the e distance: 0.38911102071456954
# with person 3 the e distance: 0.39761112903908874
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.218035833939437
# with person 2 the e distance: 0.384736973381327
# with person 3 the e distance: 0.3992348038153825
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24646610242232822
# with person 2 the e distance: 0.3905197470973071
# with person 3 the e distance: 0.3879662754301226
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24229371920957893
# with person 2 the e distance: 0.3895027245600324
# with person 3 the e distance: 0.39369522031428666
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22512011845619156
# with person 2 the e distance: 0.3858970881469961
# with person 3 the e distance: 0.4094611061275047
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24304091327677474
# with person 2 the e distance: 0.40485781972632334
# with person 3 the e distance: 0.4010638591180794
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24062182527884962
# with person 2 the e distance: 0.3858566315290872
# with person 3 the e distance: 0.38862552451137417
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23003559760860717
# with person 2 the e distance: 0.38634166859098373
# with person 3 the e distance: 0.3982735044377107
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22939314942177003
# with person 2 the e distance: 0.3938572867873225
# with person 3 the e distance: 0.38597930964812105
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22886036270535345
# with person 2 the e distance: 0.385712305005452
# with person 3 the e distance: 0.41567376187423766
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24288082044587314
# with person 2 the e distance: 0.3915499833628862
# with person 3 the e distance: 0.4007885545195748
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23659655732188847
# with person 2 the e distance: 0.379391816736708
# with person 3 the e distance: 0.39556179360422894
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23646543414974197
# with person 2 the e distance: 0.3887595821590291
# with person 3 the e distance: 0.39643760406967343
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21877618102155721
# with person 2 the e distance: 0.399834985560831
# with person 3 the e distance: 0.39117969681361187
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2307297489367865
# with person 2 the e distance: 0.3935372767920286
# with person 3 the e distance: 0.402649723979624
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2256262396257233
# with person 2 the e distance: 0.40118463752836736
# with person 3 the e distance: 0.3889999562441202
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21811579942425893
# with person 2 the e distance: 0.40781497227725155
# with person 3 the e distance: 0.40230730745839016
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21602704435539025
# with person 2 the e distance: 0.41642711614024125
# with person 3 the e distance: 0.40156786788916204
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2172526980422877
# with person 2 the e distance: 0.4040092140772056
# with person 3 the e distance: 0.4018037325801344
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22202098574051113
# with person 2 the e distance: 0.4264714954534232
# with person 3 the e distance: 0.40364895249343163
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24027379273847876
# with person 2 the e distance: 0.41749462421288036
# with person 3 the e distance: 0.39324822548572963
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2321395689319824
# with person 2 the e distance: 0.40105273312014705
# with person 3 the e distance: 0.39698692723759027
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25325966884863516
# with person 2 the e distance: 0.4097868653249335
# with person 3 the e distance: 0.40331905324909256
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22925715837078953
# with person 2 the e distance: 0.3964266985021424
# with person 3 the e distance: 0.4096526226697433
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
# ##### camera person 1 #####
# with person 1 the e distance: 0.23590540986628344
# with person 2 the e distance: 0.4026725661511478
# with person 3 the e distance: 0.4099461739337217
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23482202770447513
# with person 2 the e distance: 0.40932167566227307
# with person 3 the e distance: 0.40281846912506997
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2599336458434523
# with person 2 the e distance: 0.40336334980692373
# with person 3 the e distance: 0.40927095970917604
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23640065757880716
# with person 2 the e distance: 0.39560726268231255
# with person 3 the e distance: 0.4117447851885157
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2449368241602588
# with person 2 the e distance: 0.40993770082829134
# with person 3 the e distance: 0.4111305247017042
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23568588323522024
# with person 2 the e distance: 0.39615079050580854
# with person 3 the e distance: 0.389346211409765
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23013948818964183
# with person 2 the e distance: 0.3931892272214261
# with person 3 the e distance: 0.4013142583920192
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26174185077796497
# with person 2 the e distance: 0.4123923448222738
# with person 3 the e distance: 0.39060841829731024
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24393740242890508
# with person 2 the e distance: 0.4071324997068032
# with person 3 the e distance: 0.41268011015820205
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.233164007255761
# with person 2 the e distance: 0.39273694480611887
# with person 3 the e distance: 0.4131277949016009
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2568247468785899
# with person 2 the e distance: 0.42341969655589806
# with person 3 the e distance: 0.41581648774410934
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21986180958587434
# with person 2 the e distance: 0.4011280379029618
# with person 3 the e distance: 0.40140525974079044
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23330964721298267
# with person 2 the e distance: 0.41181997832933337
# with person 3 the e distance: 0.4020584295569869
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23939275520876985
# with person 2 the e distance: 0.41198768161195126
# with person 3 the e distance: 0.4034858458061563
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2286888839755064
# with person 2 the e distance: 0.3937488350242316
# with person 3 the e distance: 0.40448127035339565
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22861151425964257
# with person 2 the e distance: 0.3998937360619167
# with person 3 the e distance: 0.3976663747507668
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24459377681170721
# with person 2 the e distance: 0.4132308609401549
# with person 3 the e distance: 0.4214604043499589
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2392623567204022
# with person 2 the e distance: 0.42039413360320904
# with person 3 the e distance: 0.39031355910484106
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24677073480809092
# with person 2 the e distance: 0.4082021109137084
# with person 3 the e distance: 0.41528647362859583
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23745166399772974
# with person 2 the e distance: 0.41494932015134706
# with person 3 the e distance: 0.4018583132736416
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23968666895558632
# with person 2 the e distance: 0.4292930573311517
# with person 3 the e distance: 0.41077951324117734
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23063110865008757
# with person 2 the e distance: 0.4056021385617455
# with person 3 the e distance: 0.4153652567236873
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23798102994260573
# with person 2 the e distance: 0.41340879643520567
# with person 3 the e distance: 0.39865890510749075
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2509612168596859
# with person 2 the e distance: 0.42689595189065244
# with person 3 the e distance: 0.41085366452304556
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2343040367126849
# with person 2 the e distance: 0.4215385763132036
# with person 3 the e distance: 0.41342251491444054
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22300680788754998
# with person 2 the e distance: 0.40338840686294336
# with person 3 the e distance: 0.393008089587848
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23424353434742537
# with person 2 the e distance: 0.4210127789672506
# with person 3 the e distance: 0.4130849981441994
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21997026613276707
# with person 2 the e distance: 0.4247383378255925
# with person 3 the e distance: 0.3967867271562924
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23633400269134375
# with person 2 the e distance: 0.40163189392528115
# with person 3 the e distance: 0.3898880146387461
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2432762478664432
# with person 2 the e distance: 0.4021895883467433
# with person 3 the e distance: 0.3892111557746382
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2381315842404758
# with person 2 the e distance: 0.3876260898190706
# with person 3 the e distance: 0.38811968938275765
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2521965489487877
# with person 2 the e distance: 0.4267662197884646
# with person 3 the e distance: 0.3956850766777863
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2503438797322419
# with person 2 the e distance: 0.41092820230887156
# with person 3 the e distance: 0.3961445071557595
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
# ##### camera person 1 #####
# with person 1 the e distance: 0.23742674649638124
# with person 2 the e distance: 0.40845170880033216
# with person 3 the e distance: 0.3994471186789866
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24072444085878006
# with person 2 the e distance: 0.4215609814763021
# with person 3 the e distance: 0.3977462577965264
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2336672250289127
# with person 2 the e distance: 0.4042688298540113
# with person 3 the e distance: 0.40341483061401107
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24075115178186599
# with person 2 the e distance: 0.427984513723478
# with person 3 the e distance: 0.40104409222113563
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23791317485188887
# with person 2 the e distance: 0.4254195365693111
# with person 3 the e distance: 0.4104922762094827
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24826223810563489
# with person 2 the e distance: 0.42855038229537845
# with person 3 the e distance: 0.3907763408771247
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22277671180981848
# with person 2 the e distance: 0.4314141786672054
# with person 3 the e distance: 0.3924306330346361
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2502130757048064
# with person 2 the e distance: 0.4092620165866257
# with person 3 the e distance: 0.41185494009247575
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22237964833496146
# with person 2 the e distance: 0.4117691174696261
# with person 3 the e distance: 0.4069535829599993
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21784774066572354
# with person 2 the e distance: 0.42407161866337195
# with person 3 the e distance: 0.4184622261823215
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22559694734589072
# with person 2 the e distance: 0.39418522645331067
# with person 3 the e distance: 0.40143013261779353
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2336783275795563
# with person 2 the e distance: 0.41493668428180897
# with person 3 the e distance: 0.39421064884663715
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24234109486966102
# with person 2 the e distance: 0.42544273095126556
# with person 3 the e distance: 0.40838435119127287
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21901204263387553
# with person 2 the e distance: 0.43140504896311876
# with person 3 the e distance: 0.43508083954992427
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22727528168118485
# with person 2 the e distance: 0.4139841463896511
# with person 3 the e distance: 0.3986845698105462
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24604931289612222
# with person 2 the e distance: 0.4194474560363942
# with person 3 the e distance: 0.4134148281186558
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23995045479282034
# with person 2 the e distance: 0.42177112253313176
# with person 3 the e distance: 0.40313411804031263
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22500273480187957
# with person 2 the e distance: 0.4443993677606865
# with person 3 the e distance: 0.40693114199530994
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2306137456399987
# with person 2 the e distance: 0.43977148264615545
# with person 3 the e distance: 0.40222386925525827
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24067771618988668
# with person 2 the e distance: 0.4317008437167135
# with person 3 the e distance: 0.40691159765400864
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21889033689894358
# with person 2 the e distance: 0.420014093209328
# with person 3 the e distance: 0.39701305393441666
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21949242779020592
# with person 2 the e distance: 0.42489054034460794
# with person 3 the e distance: 0.4085900629345899
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23401883053589706
# with person 2 the e distance: 0.4215222968815996
# with person 3 the e distance: 0.40731156789102996
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2411106975866369
# with person 2 the e distance: 0.4232193576964899
# with person 3 the e distance: 0.41399260898206863
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2298686216481622
# with person 2 the e distance: 0.4328522560465203
# with person 3 the e distance: 0.4132466891994757
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24781875982504128
# with person 2 the e distance: 0.41381055279915746
# with person 3 the e distance: 0.42258758043779104
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2296781077488025
# with person 2 the e distance: 0.4412396129226392
# with person 3 the e distance: 0.3985375030882503
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23129226865322625
# with person 2 the e distance: 0.4312888274508895
# with person 3 the e distance: 0.3960937762292109
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2279521434061699
# with person 2 the e distance: 0.43512402545388706
# with person 3 the e distance: 0.3914153145492673
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22270136009774702
# with person 2 the e distance: 0.44452937056277664
# with person 3 the e distance: 0.3972464839916787
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23520146241401674
# with person 2 the e distance: 0.4289636944487736
# with person 3 the e distance: 0.39782073354490616
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2204835813958108
# with person 2 the e distance: 0.43481150175597705
# with person 3 the e distance: 0.40356161348307446
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21152115298091573
# with person 2 the e distance: 0.43545810026388815
# with person 3 the e distance: 0.42731737935030667
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22941386454983603
# with person 2 the e distance: 0.4508716297083495
# with person 3 the e distance: 0.43121836583658013
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2582000896108721
# with person 2 the e distance: 0.4523667875363522
# with person 3 the e distance: 0.4436522504324296
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.300988098315952
# with person 2 the e distance: 0.5002367295185518
# with person 3 the e distance: 0.46658423599418136
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26900036159034635
# with person 2 the e distance: 0.47894101195147937
# with person 3 the e distance: 0.4455092802751238
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2956863478253555
# with person 2 the e distance: 0.4794936700254921
# with person 3 the e distance: 0.4675388538745538
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2303701980756703
# with person 2 the e distance: 0.4419867911132895
# with person 3 the e distance: 0.4125663705185187
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.21221769289030282
# with person 2 the e distance: 0.426467190906503
# with person 3 the e distance: 0.4325649385214566
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24589080363339025
# with person 2 the e distance: 0.43258627023709023
# with person 3 the e distance: 0.4243387042029387
# Minimum e distance with person Roger
# May be person Roger
#
#
# Faces in camera now: ['Roger']
